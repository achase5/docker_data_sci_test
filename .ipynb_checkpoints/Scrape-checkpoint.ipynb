# %%
from bs4 import BeautifulSoup
import requests
import re
url = 'https://portland.craigslist.org/search/sss?query=rock+climbing'

# %%
r  = requests.get(url)
data = r.text
soup = BeautifulSoup(data,'lxml')
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-6-1fe0df014eb0> in <module>()
#       1 r  = requests.get(url)
#       2 data = r.text
# ----> 3 soup = BeautifulSoup(data,'lxml')
#
# c:\users\chris\appdata\local\programs\python\python36-32\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     163                     "Couldn't find a tree builder with the features you "
#     164                     "requested: %s. Do you need to install a parser library?"
# --> 165                     % ",".join(features))
#     166             builder = builder_class()
#     167             if not (original_features == builder.NAME or
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?

# %%
soup2 = soup.findAll('a', { "class" : "result-image" })

# %%
re_link = re.compile("https://(.*).html")
links = [re_link.findall(str(i)) for i in  soup2]
len(links)

# %% [markdown]
# # i

# %%
re_price = re.compile("""<span class="result-price">(.*)</span>""")
price = [re_price.findall(str(i)) for i in  soup2]
price = [[None] if len(i) == 0  else i for i in price]
price = [item for sublist in price for item in sublist]

# %%
flat_list = [item for sublist in links for item in sublist]
links = ['https://'+i+'.html' for i in flat_list]

# %%
import pandas as pd
pd.DataFrame({'x':price,'y':links})
# Out:
#           x                                                  y
# 0      None  https://portland.craigslist.org/yam/spo/d/rock...
# 1       $10  https://portland.craigslist.org/wsc/for/d/rock...
# 2       $50  https://portland.craigslist.org/mlt/for/d/yate...
# 3       $90  https://portland.craigslist.org/mlt/spo/d/rock...
# 4       $39  https://portland.craigslist.org/mlt/spo/d/rock...
# 5       $75  https://portland.craigslist.org/clc/spo/d/rock...
# 6       $60  https://portland.craigslist.org/mlt/spo/d/rock...
# 7       $15  https://portland.craigslist.org/clc/for/d/trio...
# 8      None  https://portland.craigslist.org/mlt/grq/d/carg...
# 9       $40  https://portland.craigslist.org/wsc/spo/d/madr...
# 10       $7  https://portland.craigslist.org/mlt/spo/d/acme...
# 11      $30  https://portland.craigslist.org/mlt/spo/d/clim...
# 12     $250  https://portland.craigslist.org/mlt/fuo/d/rock...
# 13     None  https://portland.craigslist.org/mlt/mad/d/rock...
# 14      $60  https://portland.craigslist.org/wsc/spo/d/stub...
# 15    $3800  https://portland.craigslist.org/clc/bik/d/2017...
# 16     $250  https://portland.craigslist.org/clc/fuo/d/cust...
# 17   $40000  https://portland.craigslist.org/clc/cto/d/2016...
# 18    $3000  https://portland.craigslist.org/mlt/mcy/d/1971...
# 19    $1300  https://portland.craigslist.org/mlt/bik/d/1999...
# 20    $3000  https://portland.craigslist.org/mlt/mcy/d/1971...
# 21      $15  https://portland.craigslist.org/wsc/grd/d/8-bu...
# 22     None  https://portland.craigslist.org/wsc/bar/d/live...
